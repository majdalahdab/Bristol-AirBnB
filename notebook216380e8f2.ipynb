# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/bristol-airbnb/listings.csv

# %%
df =  pd.read_csv('/kaggle/input/bristol-airbnb/listings.csv')

# %%
df.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   70820   https://www.airbnb.com/rooms/70820  20230328184415   2023-03-28
# 1  117122  https://www.airbnb.com/rooms/117122  20230328184415   2023-03-28
# 2  176306  https://www.airbnb.com/rooms/176306  20230328184415   2023-03-28
# 3  307634  https://www.airbnb.com/rooms/307634  20230328184415   2023-03-28
# 4  341227  https://www.airbnb.com/rooms/341227  20230328184415   2023-03-28
#
#             source                                               name  \
# 0  previous scrape                   City View - Sarah's double room.
# 1      city scrape                      City Centre-Waterside Retreat
# 2      city scrape  The White Room -  Central Bristol Art House Ga...
# 3      city scrape             'The Sunset Room' Peaceful, Clear Home
# 4      city scrape     Listed Georgian house in the heart of Bristol.
#
#                                          description  \
# 0  A good sized room with a comfy double bed and ...
# 1  My Harbourside apartment centrally located min...
# 2  A small double room in an artist's house, with...
# 3  Close to Bristol and Bath Railway Path, leadin...
# 4  This is a unique home in the heart of Montpeli...
#
#                                neighborhood_overview  \
# 0  The neighbourhood is friendly and welcoming; m...
# 1  This area is on the water and has splendid vie...
# 2  Southville is pretty darn hip, frankly. North ...
# 3  Located in the cosmopolitan and bohemian commu...
# 4  Shabby and authentic and still not gentrified,...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/b33c30be-56a0...   360195  ...
# 1  https://a0.muscache.com/pictures/f6d39021-af07...   591555  ...
# 2  https://a0.muscache.com/pictures/e1e7fdfc-9db5...   708175  ...
# 3  https://a0.muscache.com/pictures/e9a6cc15-b2ea...  1582810  ...
# 4  https://a0.muscache.com/pictures/43731fbe-289d...   237360  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.94                   4.75                4.77
# 1                        4.99                   4.97                4.88
# 2                        4.93                   4.74                4.70
# 3                        4.76                   4.79                4.62
# 4                        4.96                   4.83                4.73
#
#   license instant_bookable calculated_host_listings_count  \
# 0     NaN                f                              5
# 1     NaN                f                              1
# 2     NaN                f                              1
# 3     NaN                f                              3
# 4     NaN                f                              1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           1
# 4                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            5
# 1                                            1
# 2                                            1
# 3                                            2
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              1.56
# 1                                           0              1.21
# 2                                           0              0.37
# 3                                           0              0.45
# 4                                           0              0.82
#
# [5 rows x 75 columns]

# %%
total_days = 365
df['occupany_rate'] = total_days - df['availability_365']

# %%
df.drop(columns=['id','listing_url','scrape_id','last_scraped','source','name','description','neighborhood_overview','picture_url','host_id','host_url','host_name','host_since','host_location','host_about','host_acceptance_rate','host_is_superhost','host_thumbnail_url','host_picture_url','host_neighbourhood','host_listings_count','host_total_listings_count','host_verifications','host_has_profile_pic','host_identity_verified','neighbourhood','neighbourhood_group_cleansed','latitude','longitude','bathrooms','beds','amenities','minimum_minimum_nights','maximum_minimum_nights','minimum_maximum_nights','maximum_maximum_nights','minimum_nights_avg_ntm','maximum_nights_avg_ntm','calendar_updated','has_availability','availability_30','availability_60','availability_90','calendar_last_scraped','number_of_reviews_ltm','number_of_reviews_l30d','first_review','last_review','review_scores_accuracy','review_scores_cleanliness','review_scores_checkin','review_scores_communication','review_scores_location','review_scores_value','license','calculated_host_listings_count','calculated_host_listings_count_entire_homes','calculated_host_listings_count_private_rooms','calculated_host_listings_count_shared_rooms','reviews_per_month'], inplace=True )

# %%
df.head()
# Out:
#    host_response_time host_response_rate neighbourhood_cleansed  \
# 0      within an hour               100%          Windmill Hill
# 1      within an hour               100%                Clifton
# 2  within a few hours               100%             Bedminster
# 3  within a few hours               100%                 Easton
# 4                 NaN                NaN                 Ashley
#
#                property_type        room_type  accommodates    bathrooms_text  \
# 0  Private room in townhouse     Private room             2     1 shared bath
# 1      Private room in condo     Private room             2  2.5 shared baths
# 2  Private room in townhouse     Private room             1     1 shared bath
# 3  Private room in townhouse     Private room             2  1.5 shared baths
# 4                Entire home  Entire home/apt            12           3 baths
#
#    bedrooms    price  minimum_nights  maximum_nights  availability_365  \
# 0       1.0   $41.00               3              21                 0
# 1       1.0   $96.00               1              28               359
# 2       1.0   $32.00               5              32                75
# 3       1.0   $38.00               6            1125               176
# 4       5.0  $571.00               2              90               179
#
#    number_of_reviews  review_scores_rating instant_bookable  occupany_rate
# 0                179                  4.78                f            365
# 1                173                  4.95                f              6
# 2                 47                  4.76                f            290
# 3                 32                  4.63                f            189
# 4                109                  4.94                f            186

# %%
df.corr()
# Out:
# /tmp/ipykernel_32/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                       accommodates  bedrooms  minimum_nights  maximum_nights  \
# accommodates              1.000000  0.848796       -0.020019        0.026488
# bedrooms                  0.848796  1.000000        0.018173        0.007483
# minimum_nights           -0.020019  0.018173        1.000000       -0.023703
# maximum_nights            0.026488  0.007483       -0.023703        1.000000
# availability_365          0.050986  0.020885       -0.035166        0.109169
# number_of_reviews        -0.049356 -0.079571       -0.050201        0.058743
# review_scores_rating     -0.042948 -0.000408        0.021797       -0.123133
# occupany_rate            -0.050986 -0.020885        0.035166       -0.109169
#
#                       availability_365  number_of_reviews  \
# accommodates                  0.050986          -0.049356
# bedrooms                      0.020885          -0.079571
# minimum_nights               -0.035166          -0.050201
# maximum_nights                0.109169           0.058743
# availability_365              1.000000          -0.035280
# number_of_reviews            -0.035280           1.000000
# review_scores_rating         -0.180427           0.100690
# occupany_rate                -1.000000           0.035280
#
#                       review_scores_rating  occupany_rate
# accommodates                     -0.042948      -0.050986
# bedrooms                         -0.000408      -0.020885
# minimum_nights                    0.021797       0.035166
# maximum_nights                   -0.123133      -0.109169
# availability_365                 -0.180427      -1.000000
# number_of_reviews                 0.100690       0.035280
# review_scores_rating              1.000000       0.180427
# occupany_rate                     0.180427       1.000000

# %%
print(df.columns)
# Out:
# Index(['host_response_time', 'host_response_rate', 'neighbourhood_cleansed',
#        'property_type', 'room_type', 'accommodates', 'bathrooms_text',
#        'bedrooms', 'price', 'minimum_nights', 'maximum_nights',
#        'availability_365', 'number_of_reviews', 'review_scores_rating',
#        'instant_bookable', 'occupany_rate'],
#       dtype='object')

# %%
df['host_response_time'].value_counts()
# Out:
# within an hour        1515
# within a few hours     299
# within a day           168
# a few days or more      31
# Name: host_response_time, dtype: int64

# %%
value_counts = df['host_response_time'].value_counts(dropna=False)
print(value_counts)
# Out:
# within an hour        1515
# NaN                    316
# within a few hours     299
# within a day           168
# a few days or more      31
# Name: host_response_time, dtype: int64

# %%
mode_value = df['host_response_time'].mode()[0]
df['host_response_time'].fillna(mode_value, inplace=True)

# %%
value_counts = df['host_response_time'].value_counts(dropna=False)
print(value_counts)
#Assumption 1 All NaN values replaced with most popular
#I could've used the mean but then I would have to change dtype of each value
# Out:
# within an hour        1831
# within a few hours     299
# within a day           168
# a few days or more      31
# Name: host_response_time, dtype: int64

# %%
value_counts = df['host_response_rate'].value_counts(dropna=False)
print(value_counts)
# Out:
# 100%    1510
# NaN      316
# 98%      159
# 99%       66
# 93%       33
# 97%       32
# 90%       25
# 50%       24
# 0%        23
# 94%       23
# 80%       16
# 86%       13
# 88%       11
# 70%        9
# 95%        8
# 83%        8
# 96%        8
# 67%        6
# 91%        6
# 92%        6
# 89%        5
# 60%        5
# 75%        4
# 63%        2
# 43%        2
# 33%        2
# 40%        2
# 78%        2
# 25%        1
# 30%        1
# 87%        1
# Name: host_response_rate, dtype: int64

# %%
mean = df['host_response_rate'].mean
df['host_response_rate'].fillna(mean, inplace=True)

# %%
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py in ?(self)
#    1060             self.info(buf=buf)
#    1061             return buf.getvalue()
#    1062
#    1063         repr_params = fmt.get_dataframe_repr_params()
# -> 1064         return self.to_string(**repr_params)
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1241                 max_cols=max_cols,
#    1242                 show_dimensions=show_dimensions,
#    1243                 decimal=decimal,
#    1244             )
# -> 1245             return fmt.DataFrameRenderer(formatter).to_string(
#    1246                 buf=buf,
#    1247                 encoding=encoding,
#    1248                 line_width=line_width,
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self, buf, encoding, line_width)
#    1132         """
#    1133         from pandas.io.formats.string import StringFormatter
#    1134
#    1135         string_formatter = StringFormatter(self.fmt, line_width=line_width)
# -> 1136         string = string_formatter.to_string()
#    1137         return save_to_buffer(string, buf=buf, encoding=encoding)
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/string.py in ?(self)
#      29     def to_string(self) -> str:
# ---> 30         text = self._get_string_representation()
#      31         if self.fmt.should_show_dimensions:
#      32             text = "".join([text, self.fmt.dimensions_info])
#      33         return text
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/string.py in ?(self)
#      41     def _get_string_representation(self) -> str:
#      42         if self.fmt.frame.empty:
#      43             return self._empty_info_line
#      44
# ---> 45         strcols = self._get_strcols()
#      46
#      47         if self.line_width is None:
#      48             # no need to wrap around just print the whole frame
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/string.py in ?(self)
#      35     def _get_strcols(self) -> list[list[str]]:
# ---> 36         strcols = self.fmt.get_strcols()
#      37         if self.fmt.is_truncated:
#      38             strcols = self._insert_dot_separators(strcols)
#      39         return strcols
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#     613     def get_strcols(self) -> list[list[str]]:
#     614         """
#     615         Render a DataFrame to a list of columns (as lists of strings).
#     616         """
# --> 617         strcols = self._get_strcols_without_index()
#     618
#     619         if self.index:
#     620             str_index = self._get_formatted_index(self.tr_frame)
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#     879             cheader = str_columns[i]
#     880             header_colwidth = max(
#     881                 int(self.col_space.get(c, 0)), *(self.adj.len(x) for x in cheader)
#     882             )
# --> 883             fmt_values = self.format_col(i)
#     884             fmt_values = _make_fixed_width(
#     885                 fmt_values, self.justify, minimum=header_colwidth, adj=self.adj
#     886             )
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self, i)
#     894     def format_col(self, i: int) -> list[str]:
#     895         frame = self.tr_frame
#     896         formatter = self._get_formatter(i)
# --> 897         return format_array(
#     898             frame.iloc[:, i]._values,
#     899             formatter,
#     900             float_format=self.float_format,
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1324         leading_space=leading_space,
#    1325         quoting=quoting,
#    1326     )
#    1327
# -> 1328     return fmt_obj.get_result()
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#    1358     def get_result(self) -> list[str]:
# -> 1359         fmt_values = self._format_strings()
#    1360         return _make_fixed_width(fmt_values, self.justify)
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#    1418
#    1419         fmt_values = []
#    1420         for i, v in enumerate(vals):
#    1421             if not is_float_type[i] and leading_space:
# -> 1422                 fmt_values.append(f" {_format(v)}")
#    1423             elif is_float_type[i]:
#    1424                 fmt_values.append(float_format(v))
#    1425             else:
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(x)
#    1398             elif isinstance(x, PandasObject):
#    1399                 return str(x)
#    1400             else:
#    1401                 # object dtype
# -> 1402                 return str(formatter(x))
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py in ?(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     228         )
#     229     elif isinstance(thing, str) and quote_strings:
#     230         result = f"'{as_escaped_string(thing)}'"
#     231     else:
# --> 232         result = as_escaped_string(thing)
#     233
#     234     return result
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py in ?(thing, escape_chars)
#     204             escape_chars = list(escape_chars.keys())
#     205         else:
#     206             escape_chars = escape_chars or ()
#     207
# --> 208         result = str(thing)
#     209         for c in escape_chars:
#     210             result = result.replace(c, translate[c])
#     211         return result
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/series.py in ?(self)
#    1590         """
#    1591         Return a string representation for a particular Series.
#    1592         """
#    1593         repr_params = fmt.get_series_repr_params()
# -> 1594         return self.to_string(**repr_params)
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/series.py in ?(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1683             float_format=float_format,
#    1684             min_rows=min_rows,
#    1685             max_rows=max_rows,
#    1686         )
# -> 1687         result = formatter.to_string()
#    1688
#    1689         # catch contract violations
#    1690         if not isinstance(result, str):
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#     393         if len(series) == 0:
#     394             return f"{type(self.series).__name__}([], {footer})"
#     395
#     396         fmt_index, have_header = self._get_formatted_index()
# --> 397         fmt_values = self._get_formatted_values()
#     398
#     399         if self.is_truncated_vertically:
#     400             n_header_rows = 0
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#     380     def _get_formatted_values(self) -> list[str]:
# --> 381         return format_array(
#     382             self.tr_series._values,
#     383             None,
#     384             float_format=self.float_format,
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1324         leading_space=leading_space,
#    1325         quoting=quoting,
#    1326     )
#    1327
# -> 1328     return fmt_obj.get_result()
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#    1358     def get_result(self) -> list[str]:
# -> 1359         fmt_values = self._format_strings()
#    1360         return _make_fixed_width(fmt_values, self.justify)
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#    1418
#    1419         fmt_values = []
#    1420         for i, v in enumerate(vals):
#    1421             if not is_float_type[i] and leading_space:
# -> 1422                 fmt_values.append(f" {_format(v)}")
#    1423             elif is_float_type[i]:
#    1424                 fmt_values.append(float_format(v))
#    1425             else:
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(x)
#    1398             elif isinstance(x, PandasObject):
#    1399                 return str(x)
#    1400             else:
#    1401                 # object dtype
# -> 1402                 return str(formatter(x))
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py in ?(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     228         )
#     229     elif isinstance(thing, str) and quote_strings:
#     230         result = f"'{as_escaped_string(thing)}'"
#     231     else:
# --> 232         result = as_escaped_string(thing)
#     233
#     234     return result
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py in ?(thing, escape_chars)
#     204             escape_chars = list(escape_chars.keys())
#     205         else:
#     206             escape_chars = escape_chars or ()
#     207
# --> 208         result = str(thing)
#     209         for c in escape_chars:
#     210             result = result.replace(c, translate[c])
#     211         return result
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/series.py in ?(self)
#    1590         """
#    1591         Return a string representation for a particular Series.
#    1592         """
#    1593         repr_params = fmt.get_series_repr_params()
# -> 1594         return self.to_string(**repr_params)
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/series.py in ?(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1683             float_format=float_format,
#    1684             min_rows=min_rows,
#    1685             max_rows=max_rows,
#    1686         )
# -> 1687         result = formatter.to_string()
#    1688
#    1689         # catch contract violations
#    1690         if not isinstance(result, str):
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#     393         if len(series) == 0:
#     394             return f"{type(self.series).__name__}([], {footer})"
#     395
#     396         fmt_index, have_header = self._get_formatted_index()
# --> 397         fmt_values = self._get_formatted_values()
#     398
#     399         if self.is_truncated_vertically:
#     400             n_header_rows = 0
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#     380     def _get_formatted_values(self) -> list[str]:
# --> 381         return format_array(
#     382             self.tr_series._values,
#     383             None,
#     384             float_format=self.float_format,
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1324         leading_space=leading_space,
#    1325         quoting=quoting,
#    1326     )
#    1327
# -> 1328     return fmt_obj.get_result()
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#    1358     def get_result(self) -> list[str]:
# -> 1359         fmt_values = self._format_strings()
#    1360         return _make_fixed_width(fmt_values, self.justify)
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#    1418
#    1419         fmt_values = []
#    1420         for i, v in enumerate(vals):
#    1421             if not is_float_type[i] and leading_space:
# -> 1422                 fmt_values.append(f" {_format(v)}")
#    1423             elif is_float_type[i]:
#    1424                 fmt_values.append(float_format(v))
#    1425             else:
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(x)
#    1398             elif isinstance(x, PandasObject):
#    1399                 return str(x)
#    1400             else:
#    1401                 # object dtype
# -> 1402                 return str(formatter(x))
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py in ?(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     228         )
#     229     elif isinstance(thing, str) and quote_strings:
#     230         result = f"'{as_escaped_string(thing)}'"
#     231     else:
# --> 232         result = as_escaped_string(thing)
#     233
#     234     return result
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py in ?(thing, escape_chars)
#     204             escape_chars = list(escape_chars.keys())
#     205         else:
#     206             escape_chars = escape_chars or ()
#     207
# --> 208         result = str(thing)
#     209         for c in escape_chars:
#     210             result = result.replace(c, translate[c])
#     211         return result
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/series.py in ?(self)
#    1590         """
#    1591         Return a string representation for a particular Series.
#    1592         """
#    1593         repr_params = fmt.get_series_repr_params()
# -> 1594         return self.to_string(**repr_params)
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/series.py in ?(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1683             float_format=float_format,
#    1684             min_rows=min_rows,
#    1685             max_rows=max_rows,
#    1686         )
# -> 1687         result = formatter.to_string()
#    1688
#    1689         # catch contract violations
#    1690         if not isinstance(result, str):
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#     393         if len(series) == 0:
#     394             return f"{type(self.series).__name__}([], {footer})"
#     395
#     396         fmt_index, have_header = self._get_formatted_index()
# --> 397         fmt_values = self._get_formatted_values()
#     398
#     399         if self.is_truncated_vertically:
#     400             n_header_rows = 0
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#     380     def _get_formatted_values(self) -> list[str]:
# --> 381         return format_array(
#     382             self.tr_series._values,
#     383             None,
#     384             float_format=self.float_format,
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1324         leading_space=leading_space,
#    1325         quoting=quoting,
#    1326     )
#    1327
# -> 1328     return fmt_obj.get_result()
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#    1358     def get_result(self) -> list[str]:
# -> 1359         fmt_values = self._format_strings()
#    1360         return _make_fixed_width(fmt_values, self.justify)
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#    1418
#    1419         fmt_values = []
#    1420         for i, v in enumerate(vals):
#    1421             if not is_float_type[i] and leading_space:
# -> 1422                 fmt_values.append(f" {_format(v)}")
#    1423             elif is_float_type[i]:
#    1424                 fmt_values.append(float_format(v))
#    1425             else:
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(x)
#    1398             elif isinstance(x, PandasObject):
#    1399                 return str(x)
#    1400             else:
#    1401                 # object dtype
# -> 1402                 return str(formatter(x))
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py in ?(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     228         )
#     229     elif isinstance(thing, str) and quote_strings:
#     230         result = f"'{as_escaped_string(thing)}'"
#     231     else:
# --> 232         result = as_escaped_string(thing)
#     233
#     234     return result
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py in ?(thing, escape_chars)
#     204             escape_chars = list(escape_chars.keys())
#     205         else:
#     206             escape_chars = escape_chars or ()
#     207
# --> 208         result = str(thing)
#     209         for c in escape_chars:
#     210             result = result.replace(c, translate[c])
#     211         return result
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/series.py in ?(self)
#    1590         """
#    1591         Return a string representation for a particular Series.
#    1592         """
#    1593         repr_params = fmt.get_series_repr_params()
# -> 1594         return self.to_string(**repr_params)
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/series.py in ?(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1683             float_format=float_format,
#    1684             min_rows=min_rows,
#    1685             max_rows=max_rows,
#    1686         )
# -> 1687         result = formatter.to_string()
#    1688
#    1689         # catch contract violations
#    1690         if not isinstance(result, str):
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#     393         if len(series) == 0:
#     394             return f"{type(self.series).__name__}([], {footer})"
#     395
#     396         fmt_index, have_header = self._get_formatted_index()
# --> 397         fmt_values = self._get_formatted_values()
#     398
#     399         if self.is_truncated_vertically:
#     400             n_header_rows = 0
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#     380     def _get_formatted_values(self) -> list[str]:
# --> 381         return format_array(
#     382             self.tr_series._values,
#     383             None,
#     384             float_format=self.float_format,
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1324         leading_space=leading_space,
#    1325         quoting=quoting,
#    1326     )
#    1327
# -> 1328     return fmt_obj.get_result()
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#    1358     def get_result(self) -> list[str]:
# -> 1359         fmt_values = self._format_strings()
#    1360         return _make_fixed_width(fmt_values, self.justify)
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#    1418
#    1419         fmt_values = []
#    1420         for i, v in enumerate(vals):
#    1421             if not is_float_type[i] and leading_space:
# -> 1422                 fmt_values.append(f" {_format(v)}")
#    1423             elif is_float_type[i]:
#    1424                 fmt_values.append(float_format(v))
#    1425             else:
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(x)
#    1398             elif isinstance(x, PandasObject):
#    1399                 return str(x)
#    1400             else:
#    1401                 # object dtype
# -> 1402                 return str(formatter(x))
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py in ?(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     228         )
#     229     elif isinstance(thing, str) and quote_strings:
#     230         result = f"'{as_escaped_string(thing)}'"
#     231     else:
# --> 232         result = as_escaped_string(thing)
#     233
#     234     return result
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py in ?(thing, escape_chars)
#     204             escape_chars = list(escape_chars.keys())
#     205         else:
#     206             escape_chars = escape_chars or ()
#     207
# --> 208         result = str(thing)
#     209         for c in escape_chars:
#     210             result = result.replace(c, translate[c])
#     211         return result
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/series.py in ?(self)
#    1590         """
#    1591         Return a string representation for a particular Series.
#    1592         """
#    1593         repr_params = fmt.get_series_repr_params()
# -> 1594         return self.to_string(**repr_params)
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/series.py in ?(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1683             float_format=float_format,
#    1684             min_rows=min_rows,
#    1685             max_rows=max_rows,
#    1686         )
# -> 1687         result = formatter.to_string()
#    1688
#    1689         # catch contract violations
#    1690         if not isinstance(result, str):
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#     393         if len(series) == 0:
#     394             return f"{type(self.series).__name__}([], {footer})"
#     395
#     396         fmt_index, have_header = self._get_formatted_index()
# --> 397         fmt_values = self._get_formatted_values()
#     398
#     399         if self.is_truncated_vertically:
#     400             n_header_rows = 0
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#     380     def _get_formatted_values(self) -> list[str]:
# --> 381         return format_array(
#     382             self.tr_series._values,
#     383             None,
#     384             float_format=self.float_format,
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1324         leading_space=leading_space,
#    1325         quoting=quoting,
#    1326     )
#    1327
# -> 1328     return fmt_obj.get_result()
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#    1358     def get_result(self) -> list[str]:
# -> 1359         fmt_values = self._format_strings()
#    1360         return _make_fixed_width(fmt_values, self.justify)
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#    1418
#    1419         fmt_values = []
#    1420         for i, v in enumerate(vals):
#    1421             if not is_float_type[i] and leading_space:
# -> 1422                 fmt_values.append(f" {_format(v)}")
#    1423             elif is_float_type[i]:
#    1424                 fmt_values.append(float_format(v))
#    1425             else:
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(x)
#    1398             elif isinstance(x, PandasObject):
#    1399                 return str(x)
#    1400             else:
#    1401                 # object dtype
# -> 1402                 return str(formatter(x))
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py in ?(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     228         )
#     229     elif isinstance(thing, str) and quote_strings:
#     230         result = f"'{as_escaped_string(thing)}'"
#     231     else:
# --> 232         result = as_escaped_string(thing)
#     233
#     234     return result
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py in ?(thing, escape_chars)
#     204             escape_chars = list(escape_chars.keys())
#     205         else:
#     206             escape_chars = escape_chars or ()
#     207
# --> 208         result = str(thing)
#     209         for c in escape_chars:
#     210             result = result.replace(c, translate[c])
#     211         return result
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/series.py in ?(self)
#    1590         """
#    1591         Return a string representation for a particular Series.
#    1592         """
#    1593         repr_params = fmt.get_series_repr_params()
# -> 1594         return self.to_string(**repr_params)
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/series.py in ?(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1683             float_format=float_format,
#    1684             min_rows=min_rows,
#    1685             max_rows=max_rows,
#    1686         )
# -> 1687         result = formatter.to_string()
#    1688
#    1689         # catch contract violations
#    1690         if not isinstance(result, str):
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#     393         if len(series) == 0:
#     394             return f"{type(self.series).__name__}([], {footer})"
#     395
#     396         fmt_index, have_header = self._get_formatted_index()
# --> 397         fmt_values = self._get_formatted_values()
#     398
#     399         if self.is_truncated_vertically:
#     400             n_header_rows = 0
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#     380     def _get_formatted_values(self) -> list[str]:
# --> 381         return format_array(
#     382             self.tr_series._values,
#     383             None,
#     384             float_format=self.float_format,
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1324         leading_space=leading_space,
#    1325         quoting=quoting,
#    1326     )
#    1327
# -> 1328     return fmt_obj.get_result()
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#    1358     def get_result(self) -> list[str]:
# -> 1359         fmt_values = self._format_strings()
#    1360         return _make_fixed_width(fmt_values, self.justify)
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#    1418
#    1419         fmt_values = []
#    1420         for i, v in enumerate(vals):
#    1421             if not is_float_type[i] and leading_space:
# -> 1422                 fmt_values.append(f" {_format(v)}")
#    1423             elif is_float_type[i]:
#    1424                 fmt_values.append(float_format(v))
#    1425             else:
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(x)
#    1398             elif isinstance(x, PandasObject):
#    1399                 return str(x)
#    1400             else:
#    1401                 # object dtype
# -> 1402                 return str(formatter(x))
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py in ?(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     228         )
#     229     elif isinstance(thing, str) and quote_strings:
#     230         result = f"'{as_escaped_string(thing)}'"
#     231     else:
# --> 232         result = as_escaped_string(thing)
#     233
#     234     return result
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py in ?(thing, escape_chars)
#     204             escape_chars = list(escape_chars.keys())
#     205         else:
#     206             escape_chars = escape_chars or ()
#     207
# --> 208         result = str(thing)
#     209         for c in escape_chars:
#     210             result = result.replace(c, translate[c])
#     211         return result
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/series.py in ?(self)
#    1590         """
#    1591         Return a string representation for a particular Series.
#    1592         """
#    1593         repr_params = fmt.get_series_repr_params()
# -> 1594         return self.to_string(**repr_params)
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/series.py in ?(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1683             float_format=float_format,
#    1684             min_rows=min_rows,
#    1685             max_rows=max_rows,
#    1686         )
# -> 1687         result = formatter.to_string()
#    1688
#    1689         # catch contract violations
#    1690         if not isinstance(result, str):
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#     393         if len(series) == 0:
#     394             return f"{type(self.series).__name__}([], {footer})"
#     395
#     396         fmt_index, have_header = self._get_formatted_index()
# --> 397         fmt_values = self._get_formatted_values()
#     398
#     399         if self.is_truncated_vertically:
#     400             n_header_rows = 0
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#     380     def _get_formatted_values(self) -> list[str]:
# --> 381         return format_array(
#     382             self.tr_series._values,
#     383             None,
#     384             float_format=self.float_format,
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1324         leading_space=leading_space,
#    1325         quoting=quoting,
#    1326     )
#    1327
# -> 1328     return fmt_obj.get_result()
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#    1358     def get_result(self) -> list[str]:
# -> 1359         fmt_values = self._format_strings()
#    1360         return _make_fixed_width(fmt_values, self.justify)
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#    1418
#    1419         fmt_values = []
#    1420         for i, v in enumerate(vals):
#    1421             if not is_float_type[i] and leading_space:
# -> 1422                 fmt_values.append(f" {_format(v)}")
#    1423             elif is_float_type[i]:
#    1424                 fmt_values.append(float_format(v))
#    1425             else:
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(x)
#    1398             elif isinstance(x, PandasObject):
#    1399                 return str(x)
#    1400             else:
#    1401                 # object dtype
# -> 1402                 return str(formatter(x))
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py in ?(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     228         )
#     229     elif isinstance(thing, str) and quote_strings:
#     230         result = f"'{as_escaped_string(thing)}'"
#     231     else:
# --> 232         result = as_escaped_string(thing)
#     233
#     234     return result
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py in ?(thing, escape_chars)
#     204             escape_chars = list(escape_chars.keys())
#     205         else:
#     206             escape_chars = escape_chars or ()
#     207
# --> 208         result = str(thing)
#     209         for c in escape_chars:
#     210             result = result.replace(c, translate[c])
#     211         return result
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/series.py in ?(self)
#    1590         """
#    1591         Return a string representation for a particular Series.
#    1592         """
#    1593         repr_params = fmt.get_series_repr_params()
# -> 1594         return self.to_string(**repr_params)
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/series.py in ?(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1683             float_format=float_format,
#    1684             min_rows=min_rows,
#    1685             max_rows=max_rows,
#    1686         )
# -> 1687         result = formatter.to_string()
#    1688
#    1689         # catch contract violations
#    1690         if not isinstance(result, str):
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#     393         if len(series) == 0:
#     394             return f"{type(self.series).__name__}([], {footer})"
#     395
#     396         fmt_index, have_header = self._get_formatted_index()
# --> 397         fmt_values = self._get_formatted_values()
#     398
#     399         if self.is_truncated_vertically:
#     400             n_header_rows = 0
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#     380     def _get_formatted_values(self) -> list[str]:
# --> 381         return format_array(
#     382             self.tr_series._values,
#     383             None,
#     384             float_format=self.float_format,
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1324         leading_space=leading_space,
#    1325         quoting=quoting,
#    1326     )
#    1327
# -> 1328     return fmt_obj.get_result()
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#    1358     def get_result(self) -> list[str]:
# -> 1359         fmt_values = self._format_strings()
#    1360         return _make_fixed_width(fmt_values, self.justify)
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#    1418
#    1419         fmt_values = []
#    1420         for i, v in enumerate(vals):
#    1421             if not is_float_type[i] and leading_space:
# -> 1422                 fmt_values.append(f" {_format(v)}")
#    1423             elif is_float_type[i]:
#    1424                 fmt_values.append(float_format(v))
#    1425             else:
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(x)
#    1398             elif isinstance(x, PandasObject):
#    1399                 return str(x)
#    1400             else:
#    1401                 # object dtype
# -> 1402                 return str(formatter(x))
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py in ?(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     228         )
#     229     elif isinstance(thing, str) and quote_strings:
#     230         result = f"'{as_escaped_string(thing)}'"
#     231     else:
# --> 232         result = as_escaped_string(thing)
#     233
#     234     return result
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py in ?(thing, escape_chars)
#     204             escape_chars = list(escape_chars.keys())
#     205         else:
#     206             escape_chars = escape_chars or ()
#     207
# --> 208         result = str(thing)
#     209         for c in escape_chars:
#     210             result = result.replace(c, translate[c])
#     211         return result
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/series.py in ?(self)
#    1590         """
#    1591         Return a string representation for a particular Series.
#    1592         """
#    1593         repr_params = fmt.get_series_repr_params()
# -> 1594         return self.to_string(**repr_params)
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/series.py in ?(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1683             float_format=float_format,
#    1684             min_rows=min_rows,
#    1685             max_rows=max_rows,
#    1686         )
# -> 1687         result = formatter.to_string()
#    1688
#    1689         # catch contract violations
#    1690         if not isinstance(result, str):
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#     393         if len(series) == 0:
#     394             return f"{type(self.series).__name__}([], {footer})"
#     395
#     396         fmt_index, have_header = self._get_formatted_index()
# --> 397         fmt_values = self._get_formatted_values()
#     398
#     399         if self.is_truncated_vertically:
#     400             n_header_rows = 0
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#     380     def _get_formatted_values(self) -> list[str]:
# --> 381         return format_array(
#     382             self.tr_series._values,
#     383             None,
#     384             float_format=self.float_format,
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1324         leading_space=leading_space,
#    1325         quoting=quoting,
#    1326     )
#    1327
# -> 1328     return fmt_obj.get_result()
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#    1358     def get_result(self) -> list[str]:
# -> 1359         fmt_values = self._format_strings()
#    1360         return _make_fixed_width(fmt_values, self.justify)
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#    1418
#    1419         fmt_values = []
#    1420         for i, v in enumerate(vals):
#    1421             if not is_float_type[i] and leading_space:
# -> 1422                 fmt_values.append(f" {_format(v)}")
#    1423             elif is_float_type[i]:
#    1424                 fmt_values.append(float_format(v))
#    1425             else:
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(x)
#    1398             elif isinstance(x, PandasObject):
#    1399                 return str(x)
#    1400             else:
#    1401                 # object dtype
# -> 1402                 return str(formatter(x))
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py in ?(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     228         )
#     229     elif isinstance(thing, str) and quote_strings:
#     230         result = f"'{as_escaped_string(thing)}'"
#     231     else:
# --> 232         result = as_escaped_string(thing)
#     233
#     234     return result
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py in ?(thing, escape_chars)
#     204             escape_chars = list(escape_chars.keys())
#     205         else:
#     206             escape_chars = escape_chars or ()
#     207
# --> 208         result = str(thing)
#     209         for c in escape_chars:
#     210             result = result.replace(c, translate[c])
#     211         return result
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/series.py in ?(self)
#    1590         """
#    1591         Return a string representation for a particular Series.
#    1592         """
#    1593         repr_params = fmt.get_series_repr_params()
# -> 1594         return self.to_string(**repr_params)
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/series.py in ?(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1683             float_format=float_format,
#    1684             min_rows=min_rows,
#    1685             max_rows=max_rows,
#    1686         )
# -> 1687         result = formatter.to_string()
#    1688
#    1689         # catch contract violations
#    1690         if not isinstance(result, str):
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#     393         if len(series) == 0:
#     394             return f"{type(self.series).__name__}([], {footer})"
#     395
#     396         fmt_index, have_header = self._get_formatted_index()
# --> 397         fmt_values = self._get_formatted_values()
#     398
#     399         if self.is_truncated_vertically:
#     400             n_header_rows = 0
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#     380     def _get_formatted_values(self) -> list[str]:
# --> 381         return format_array(
#     382             self.tr_series._values,
#     383             None,
#     384             float_format=self.float_format,
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1324         leading_space=leading_space,
#    1325         quoting=quoting,
#    1326     )
#    1327
# -> 1328     return fmt_obj.get_result()
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#    1358     def get_result(self) -> list[str]:
# -> 1359         fmt_values = self._format_strings()
#    1360         return _make_fixed_width(fmt_values, self.justify)
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#    1418
#    1419         fmt_values = []
#    1420         for i, v in enumerate(vals):
#    1421             if not is_float_type[i] and leading_space:
# -> 1422                 fmt_values.append(f" {_format(v)}")
#    1423             elif is_float_type[i]:
#    1424                 fmt_values.append(float_format(v))
#    1425             else:
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(x)
#    1398             elif isinstance(x, PandasObject):
#    1399                 return str(x)
#    1400             else:
#    1401                 # object dtype
# -> 1402                 return str(formatter(x))
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py in ?(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     228         )
#     229     elif isinstance(thing, str) and quote_strings:
#     230         result = f"'{as_escaped_string(thing)}'"
#     231     else:
# --> 232         result = as_escaped_string(thing)
#     233
#     234     return result
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py in ?(thing, escape_chars)
#     204             escape_chars = list(escape_chars.keys())
#     205         else:
#     206             escape_chars = escape_chars or ()
#     207
# --> 208         result = str(thing)
#     209         for c in escape_chars:
#     210             result = result.replace(c, translate[c])
#     211         return result
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/series.py in ?(self)
#    1590         """
#    1591         Return a string representation for a particular Series.
#    1592         """
#    1593         repr_params = fmt.get_series_repr_params()
# -> 1594         return self.to_string(**repr_params)
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/series.py in ?(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1683             float_format=float_format,
#    1684             min_rows=min_rows,
#    1685             max_rows=max_rows,
#    1686         )
# -> 1687         result = formatter.to_string()
#    1688
#    1689         # catch contract violations
#    1690         if not isinstance(result, str):
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#     393         if len(series) == 0:
#     394             return f"{type(self.series).__name__}([], {footer})"
#     395
#     396         fmt_index, have_header = self._get_formatted_index()
# --> 397         fmt_values = self._get_formatted_values()
#     398
#     399         if self.is_truncated_vertically:
#     400             n_header_rows = 0
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#     380     def _get_formatted_values(self) -> list[str]:
# --> 381         return format_array(
#     382             self.tr_series._values,
#     383             None,
#     384             float_format=self.float_format,
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1324         leading_space=leading_space,
#    1325         quoting=quoting,
#    1326     )
#    1327
# -> 1328     return fmt_obj.get_result()
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#    1358     def get_result(self) -> list[str]:
# -> 1359         fmt_values = self._format_strings()
#    1360         return _make_fixed_width(fmt_values, self.justify)
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#    1418
#    1419         fmt_values = []
#    1420         for i, v in enumerate(vals):
#    1421             if not is_float_type[i] and leading_space:
# -> 1422                 fmt_values.append(f" {_format(v)}")
#    1423             elif is_float_type[i]:
#    1424                 fmt_values.append(float_format(v))
#    1425             else:
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(x)
#    1398             elif isinstance(x, PandasObject):
#    1399                 return str(x)
#    1400             else:
#    1401                 # object dtype
# -> 1402                 return str(formatter(x))
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py in ?(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     228         )
#     229     elif isinstance(thing, str) and quote_strings:
#     230         result = f"'{as_escaped_string(thing)}'"
#     231     else:
# --> 232         result = as_escaped_string(thing)
#     233
#     234     return result
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py in ?(thing, escape_chars)
#     204             escape_chars = list(escape_chars.keys())
#     205         else:
#     206             escape_chars = escape_chars or ()
#     207
# --> 208         result = str(thing)
#     209         for c in escape_chars:
#     210             result = result.replace(c, translate[c])
#     211         return result
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/series.py in ?(self)
#    1590         """
#    1591         Return a string representation for a particular Series.
#    1592         """
#    1593         repr_params = fmt.get_series_repr_params()
# -> 1594         return self.to_string(**repr_params)
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/series.py in ?(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1683             float_format=float_format,
#    1684             min_rows=min_rows,
#    1685             max_rows=max_rows,
#    1686         )
# -> 1687         result = formatter.to_string()
#    1688
#    1689         # catch contract violations
#    1690         if not isinstance(result, str):
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#     393         if len(series) == 0:
#     394             return f"{type(self.series).__name__}([], {footer})"
#     395
#     396         fmt_index, have_header = self._get_formatted_index()
# --> 397         fmt_values = self._get_formatted_values()
#     398
#     399         if self.is_truncated_vertically:
#     400             n_header_rows = 0
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#     380     def _get_formatted_values(self) -> list[str]:
# --> 381         return format_array(
#     382             self.tr_series._values,
#     383             None,
#     384             float_format=self.float_format,
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1324         leading_space=leading_space,
#    1325         quoting=quoting,
#    1326     )
#    1327
# -> 1328     return fmt_obj.get_result()
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#    1358     def get_result(self) -> list[str]:
# -> 1359         fmt_values = self._format_strings()
#    1360         return _make_fixed_width(fmt_values, self.justify)
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(self)
#    1418
#    1419         fmt_values = []
#    1420         for i, v in enumerate(vals):
#    1421             if not is_float_type[i] and leading_space:
# -> 1422                 fmt_values.append(f" {_format(v)}")
#    1423             elif is_float_type[i]:
#    1424                 fmt_values.append(float_format(v))
#    1425             else:
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py in ?(x)
#    1398             elif isinstance(x, PandasObject):
#    1399                 return str(x)
#    1400             else:
#    1401                 # object dtype
# -> 1402                 return str(formatter(x))
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py in ?(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     228         )
#     229     elif isinstance(thing, str) and quote_strings:
#     230         result = f"'{as_escaped_string(thing)}'"
#     231     else:
# --> 232         result = as_escaped_string(thing)
#     233
#     234     return result
#
# /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py in ?(thing, escape_chars)
#     204             escape_chars = list(escape_chars.keys())
#     205         else:
# ...
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py:1402, in GenericArrayFormatter._format_strings.<locals>._format(x)
#    1399     return str(x)
#    1400 else:
#    1401     # object dtype
# -> 1402     return str(formatter(x))
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py:232, in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     230     result = f"'{as_escaped_string(thing)}'"
#     231 else:
# --> 232     result = as_escaped_string(thing)
#     234 return result
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py:208, in pprint_thing.<locals>.as_escaped_string(thing, escape_chars)
#     205 else:
#     206     escape_chars = escape_chars or ()
# --> 208 result = str(thing)
#     209 for c in escape_chars:
#     210     result = result.replace(c, translate[c])
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/series.py:1594, in Series.__repr__(self)
#    1590 """
#    1591 Return a string representation for a particular Series.
#    1592 """
#    1593 repr_params = fmt.get_series_repr_params()
# -> 1594 return self.to_string(**repr_params)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/series.py:1687, in Series.to_string(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1641 """
#    1642 Render a string representation of the Series.
#    1643
#    (...)
#    1673     String representation of Series if ``buf=None``, otherwise None.
#    1674 """
#    1675 formatter = fmt.SeriesFormatter(
#    1676     self,
#    1677     name=name,
#    (...)
#    1685     max_rows=max_rows,
#    1686 )
# -> 1687 result = formatter.to_string()
#    1689 # catch contract violations
#    1690 if not isinstance(result, str):
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py:397, in SeriesFormatter.to_string(self)
#     394     return f"{type(self.series).__name__}([], {footer})"
#     396 fmt_index, have_header = self._get_formatted_index()
# --> 397 fmt_values = self._get_formatted_values()
#     399 if self.is_truncated_vertically:
#     400     n_header_rows = 0
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py:381, in SeriesFormatter._get_formatted_values(self)
#     380 def _get_formatted_values(self) -> list[str]:
# --> 381     return format_array(
#     382         self.tr_series._values,
#     383         None,
#     384         float_format=self.float_format,
#     385         na_rep=self.na_rep,
#     386         leading_space=self.index,
#     387     )
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py:1328, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1313     digits = get_option("display.precision")
#    1315 fmt_obj = fmt_klass(
#    1316     values,
#    1317     digits=digits,
#    (...)
#    1325     quoting=quoting,
#    1326 )
# -> 1328 return fmt_obj.get_result()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py:1359, in GenericArrayFormatter.get_result(self)
#    1358 def get_result(self) -> list[str]:
# -> 1359     fmt_values = self._format_strings()
#    1360     return _make_fixed_width(fmt_values, self.justify)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py:1422, in GenericArrayFormatter._format_strings(self)
#    1420 for i, v in enumerate(vals):
#    1421     if not is_float_type[i] and leading_space:
# -> 1422         fmt_values.append(f" {_format(v)}")
#    1423     elif is_float_type[i]:
#    1424         fmt_values.append(float_format(v))
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py:1402, in GenericArrayFormatter._format_strings.<locals>._format(x)
#    1399     return str(x)
#    1400 else:
#    1401     # object dtype
# -> 1402     return str(formatter(x))
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py:232, in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     230     result = f"'{as_escaped_string(thing)}'"
#     231 else:
# --> 232     result = as_escaped_string(thing)
#     234 return result
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py:208, in pprint_thing.<locals>.as_escaped_string(thing, escape_chars)
#     205 else:
#     206     escape_chars = escape_chars or ()
# --> 208 result = str(thing)
#     209 for c in escape_chars:
#     210     result = result.replace(c, translate[c])
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/series.py:1594, in Series.__repr__(self)
#    1590 """
#    1591 Return a string representation for a particular Series.
#    1592 """
#    1593 repr_params = fmt.get_series_repr_params()
# -> 1594 return self.to_string(**repr_params)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/series.py:1687, in Series.to_string(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1641 """
#    1642 Render a string representation of the Series.
#    1643
#    (...)
#    1673     String representation of Series if ``buf=None``, otherwise None.
#    1674 """
#    1675 formatter = fmt.SeriesFormatter(
#    1676     self,
#    1677     name=name,
#    (...)
#    1685     max_rows=max_rows,
#    1686 )
# -> 1687 result = formatter.to_string()
#    1689 # catch contract violations
#    1690 if not isinstance(result, str):
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py:397, in SeriesFormatter.to_string(self)
#     394     return f"{type(self.series).__name__}([], {footer})"
#     396 fmt_index, have_header = self._get_formatted_index()
# --> 397 fmt_values = self._get_formatted_values()
#     399 if self.is_truncated_vertically:
#     400     n_header_rows = 0
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py:381, in SeriesFormatter._get_formatted_values(self)
#     380 def _get_formatted_values(self) -> list[str]:
# --> 381     return format_array(
#     382         self.tr_series._values,
#     383         None,
#     384         float_format=self.float_format,
#     385         na_rep=self.na_rep,
#     386         leading_space=self.index,
#     387     )
#
#     [... skipping similar frames: Series.__repr__ at line 1594 (207 times), GenericArrayFormatter._format_strings.<locals>._format at line 1402 (207 times), GenericArrayFormatter._format_strings at line 1422 (207 times), pprint_thing.<locals>.as_escaped_string at line 208 (207 times), format_array at line 1328 (207 times), GenericArrayFormatter.get_result at line 1359 (207 times), pprint_thing at line 232 (207 times), SeriesFormatter._get_formatted_values at line 381 (206 times), Series.to_string at line 1687 (206 times), SeriesFormatter.to_string at line 397 (206 times)]
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/series.py:1687, in Series.to_string(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1641 """
#    1642 Render a string representation of the Series.
#    1643
#    (...)
#    1673     String representation of Series if ``buf=None``, otherwise None.
#    1674 """
#    1675 formatter = fmt.SeriesFormatter(
#    1676     self,
#    1677     name=name,
#    (...)
#    1685     max_rows=max_rows,
#    1686 )
# -> 1687 result = formatter.to_string()
#    1689 # catch contract violations
#    1690 if not isinstance(result, str):
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py:397, in SeriesFormatter.to_string(self)
#     394     return f"{type(self.series).__name__}([], {footer})"
#     396 fmt_index, have_header = self._get_formatted_index()
# --> 397 fmt_values = self._get_formatted_values()
#     399 if self.is_truncated_vertically:
#     400     n_header_rows = 0
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py:381, in SeriesFormatter._get_formatted_values(self)
#     380 def _get_formatted_values(self) -> list[str]:
# --> 381     return format_array(
#     382         self.tr_series._values,
#     383         None,
#     384         float_format=self.float_format,
#     385         na_rep=self.na_rep,
#     386         leading_space=self.index,
#     387     )
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py:1328, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting)
#    1313     digits = get_option("display.precision")
#    1315 fmt_obj = fmt_klass(
#    1316     values,
#    1317     digits=digits,
#    (...)
#    1325     quoting=quoting,
#    1326 )
# -> 1328 return fmt_obj.get_result()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py:1359, in GenericArrayFormatter.get_result(self)
#    1358 def get_result(self) -> list[str]:
# -> 1359     fmt_values = self._format_strings()
#    1360     return _make_fixed_width(fmt_values, self.justify)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py:1422, in GenericArrayFormatter._format_strings(self)
#    1420 for i, v in enumerate(vals):
#    1421     if not is_float_type[i] and leading_space:
# -> 1422         fmt_values.append(f" {_format(v)}")
#    1423     elif is_float_type[i]:
#    1424         fmt_values.append(float_format(v))
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py:1402, in GenericArrayFormatter._format_strings.<locals>._format(x)
#    1399     return str(x)
#    1400 else:
#    1401     # object dtype
# -> 1402     return str(formatter(x))
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py:232, in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     230     result = f"'{as_escaped_string(thing)}'"
#     231 else:
# --> 232     result = as_escaped_string(thing)
#     234 return result
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/formats/printing.py:208, in pprint_thing.<locals>.as_escaped_string(thing, escape_chars)
#     205 else:
#     206     escape_chars = escape_chars or ()
# --> 208 result = str(thing)
#     209 for c in escape_chars:
#     210     result = result.replace(c, translate[c])
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/series.py:1594, in Series.__repr__(self)
#    1590 """
#    1591 Return a string representation for a particular Series.
#    1592 """
#    1593 repr_params = fmt.get_series_repr_params()
# -> 1594 return self.to_string(**repr_params)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/series.py:1675, in Series.to_string(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1628 def to_string(
#    1629     self,
#    1630     buf: FilePath | WriteBuffer[str] | None = None,
#    (...)
#    1639     min_rows: int | None = None,
#    1640 ) -> str | None:
#    1641     """
#    1642     Render a string representation of the Series.
#    1643
#    (...)
#    1673         String representation of Series if ``buf=None``, otherwise None.
#    1674     """
# -> 1675     formatter = fmt.SeriesFormatter(
#    1676         self,
#    1677         name=name,
#    1678         length=length,
#    1679         header=header,
#    1680         index=index,
#    1681         dtype=dtype,
#    1682         na_rep=na_rep,
#    1683         float_format=float_format,
#    1684         min_rows=min_rows,
#    1685         max_rows=max_rows,
#    1686     )
#    1687     result = formatter.to_string()
#    1689     # catch contract violations
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py:299, in SeriesFormatter.__init__(self, series, buf, length, header, index, na_rep, name, float_format, dtype, max_rows, min_rows)
#     296 self.dtype = dtype
#     297 self.adj = get_adjustment()
# --> 299 self._chk_truncate()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/formats/format.py:321, in SeriesFormatter._chk_truncate(self)
#     319     else:
#     320         row_num = max_rows // 2
# --> 321         series = concat((series.iloc[:row_num], series.iloc[-row_num:]))
#     322     self.tr_row_num = row_num
#     323 else:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1602, in _iLocIndexer._getitem_axis(self, key, axis)
#    1596     raise IndexError(
#    1597         "DataFrame indexer is not allowed for .iloc\n"
#    1598         "Consider using .loc for automatic alignment."
#    1599     )
#    1601 if isinstance(key, slice):
# -> 1602     return self._get_slice_axis(key, axis=axis)
#    1604 if is_iterator(key):
#    1605     key = list(key)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1638, in _iLocIndexer._get_slice_axis(self, slice_obj, axis)
#    1636 labels = obj._get_axis(axis)
#    1637 labels._validate_positional_slice(slice_obj)
# -> 1638 return self.obj._slice(slice_obj, axis=axis)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/series.py:964, in Series._slice(self, slobj, axis)
#     961 def _slice(self, slobj: slice, axis: int = 0) -> Series:
#     962     # axis kwarg is retained for compat with NDFrame method
#     963     #  _slice is *always* positional
# --> 964     return self._get_values(slobj)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/series.py:1070, in Series._get_values(self, indexer)
#    1068 def _get_values(self, indexer: slice | npt.NDArray[np.bool_]) -> Series:
#    1069     new_mgr = self._mgr.getitem_mgr(indexer)
# -> 1070     return self._constructor(new_mgr).__finalize__(self)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/series.py:364, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     362         object.__setattr__(self, "_name", name)
#     363     else:
# --> 364         self.name = name
#     365     return
#     367 # we are called internally, so short-circuit
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:5924, in NDFrame.__setattr__(self, name, value)
#    5922     object.__setattr__(self, name, value)
#    5923 elif name in self._metadata:
# -> 5924     object.__setattr__(self, name, value)
#    5925 else:
#    5926     try:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/series.py:663, in Series.name(self, value)
#     661 @name.setter
#     662 def name(self, value: Hashable) -> None:
# --> 663     validate_all_hashable(value, error_name=f"{type(self).__name__}.name")
#     664     object.__setattr__(self, "_name", value)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/dtypes/common.py:1744, in validate_all_hashable(error_name, *args)
#    1725 def validate_all_hashable(*args, error_name: str | None = None) -> None:
#    1726     """
#    1727     Return None if all args are hashable, else raise a TypeError.
#    1728
#    (...)
#    1742     None
#    1743     """
# -> 1744     if not all(is_hashable(arg) for arg in args):
#    1745         if error_name:
#    1746             raise TypeError(f"{error_name} must be a hashable type")
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/dtypes/common.py:1744, in <genexpr>(.0)
#    1725 def validate_all_hashable(*args, error_name: str | None = None) -> None:
#    1726     """
#    1727     Return None if all args are hashable, else raise a TypeError.
#    1728
#    (...)
#    1742     None
#    1743     """
# -> 1744     if not all(is_hashable(arg) for arg in args):
#    1745         if error_name:
#    1746             raise TypeError(f"{error_name} must be a hashable type")
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/dtypes/inference.py:356, in is_hashable(obj)
#     348 # Unfortunately, we can't use isinstance(obj, collections.abc.Hashable),
#     349 # which can be faster than calling hash. That is because numpy scalars
#     350 # fail this test.
#     351
#     352 # Reconsider this decision once this numpy bug is fixed:
#     353 # https://github.com/numpy/numpy/issues/5562
#     355 try:
# --> 356     hash(obj)
#     357 except TypeError:
#     358     return False
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
